# %% [markdown]
# <a href="https://colab.research.google.com/github/BarryDeCicco/Jupyter_Notebook_Code_Fragments/blob/main/Jupyter_Notebook_Code_Fragments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **If you are getting save problems, with Gitub giving you  'Invalid Notebook  There was an error rendering your Notebook: the 'state' key is missing from 'metadata.widgets'.  Add 'state' to each, or remove 'metadata.widgets'. Using nbformat v5.10.4 and nbconvert v7.16.6', try this**

# %%
claude.ai/chat/cb2d9ac4-9f53-4e04-b5d9-0f035f2424ee
